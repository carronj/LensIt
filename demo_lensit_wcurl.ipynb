# %% [markdown]
# # Iterative lensing estimation demo (CMB-S4).
#
# This notebook goes through an example of joint lensing gradient and curl iterative reconstruction, from polarization Q and U CMB data on 650 square degrees, under ideal conditions (no masking, homogeneous noise, etc), with pixel size 1.5 arcmin. Specifically, we proceed as follows
# 1. We build the quadratic estimator and initial curvature estimates
# 2. We setup the iterator instance
# 3. We perform the iterations
# 4. We have a quick look at the quality of the lensing map reconstruction
#
# It should take or minute or so to perform all iterations from the starting point.
#
# Before starting, set the environment variable LENSIT to somewhere that is safe to write. A bunch of stuff might get cached.

# %%
# %matplotlib inline
import pylab as pl
import numpy as np
import lensit as li
import os
EXP = 'S4_SPDP'
nlev_t, nlev_p, beam, ellmin, ellmax = li.get_config(EXP)

# %% [markdown]
# ### 1. We build the quadratic estimator and initial curvature estimates:

# %%
def get_starting_point(idx): 
    """
    This returns initial data for simulation index 'idx' from a CMB-S4 simulation library.
    On first call the simulation library will generate all simulations phases, hence might take a little while.
    """ 
    sims = li.get_maps_lib(EXP, 10, HDres=11, wrotation=True, nsims=1) # Simulation-library for configuration 'S4'. 
                                         # Parameters 10, 11 produces data on 645 sq. deg, 
                                         # with lensed CMB's generated at 0.75 arcmin resolution, 
                                         # but data collected at 1.5 arcmin resolution. 
    
    isocov = li.get_isocov(EXP, 10, 11) # Isotropic filtering instance, that can used for Q.E. calculation
                                         # and other things.isocov.lib_datalm defines the mode-filtering applied 
                                         # the data, and isocov.lib_skyalm the band-limits of the unlensed sky.
    print(" I will be using data from ell=%s to ell=%s only"%(isocov.lib_datalm.ellmin, isocov.lib_datalm.ellmax))
    print(" The sky band-limit is ell=%s"%(isocov.lib_skyalm.ellmax))
    
    lib_qlm = isocov.lib_skyalm #: This means we will reconstruct the lensing potential for all unlensed sky modes.
    def cli(cl):
        ret = np.zeros_like(cl)
        ret[np.where(cl > 0)] = 1./cl[np.where(cl > 0)]
        return ret
    
    # We now build the Wiener-filtered quadratic estimator. We use lensed CMB spectra in the weights.
    datalms = np.array([isocov.lib_datalm.map2alm(m) for m in sims.get_sim_qumap(idx)]) 
    H0lens =  [cli(isocov.get_N0cls('QU', lib_qlm, use_cls_len=True)[0]), cli(isocov.get_N0cls('QU', lib_qlm, use_cls_len=True)[1])]
    POlm0 = 0.5 * isocov.get_qlms('QU',  isocov.get_iblms('QU', datalms, use_cls_len=True)[0], lib_qlm, 
                                 use_cls_len=True)
    
    # Normalization and Wiener-filtering:
    cpp_prior = li.get_fidcls(wrotationCls=True)[0]['pp'][:lib_qlm.ellmax+1]
    coo_prior = li.get_fidcls(wrotationCls=True)[0]['oo'][:lib_qlm.ellmax+1]
    lib_qlm.almxfl(POlm0[0], cli(H0lens[0] + cli(cpp_prior)), inplace=True)
    lib_qlm.almxfl(POlm0[1], cli(H0lens[1] + cli(coo_prior)), inplace=True)
    
    # Initial likelihood curvature guess. We use here N0 as calculated with unlensed CMB spectra:
    H0unls =  [cli(isocov.get_N0cls('QU', lib_qlm, use_cls_len=False)[0]), cli(isocov.get_N0cls('QU', lib_qlm, use_cls_len=False)[1])]
    return POlm0, lib_qlm, datalms, isocov.lib_datalm, H0unls, H0lens

POlm0, lib_qlm, datalms, lib_datalm, H0s, H0len = get_starting_point(0)
# Out:
#  I will be using data from ell=14 to ell=4096 only
#  The sky band-limit is ell=5120
#   lensit.ffs_covs.ffs_cov   [00:00:00]  (total [00:00:00])   inverse len Pmats  curvpOlm
#   lensit.ffs_covs.ffs_cov   [00:00:00]  (total [00:00:00])   Fxx , part 1  curvpOlm
#   lensit.ffs_covs.ffs_cov   [00:00:00]  (total [00:00:00])   Fyy , part 1  curvpOlm
#   lensit.ffs_covs.ffs_cov   [00:00:00]  (total [00:00:01])   Fxy , part 1  curvpOlm
#   lensit.ffs_covs.ffs_cov   [00:00:00]  (total [00:00:01])   Fxx , part 2  curvpOlm
#   lensit.ffs_covs.ffs_cov   [00:00:00]  (total [00:00:01])   Fyy , part 2  curvpOlm
#   lensit.ffs_covs.ffs_cov   [00:00:00]  (total [00:00:02])   Fxy , part 2  curvpOlm
#      [00:00:02]  (total [00:00:02])   get_qlm_resplm:: get curvature matrices
#      [00:00:00]  (total [00:00:02])   get_qlm_resplm:: inversion
#      _get_pmati:: cached /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/Covs/S4_SPDP/LD10HD11/QU_Pmatinv_len_00.npy
#      _get_pmati:: cached /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/Covs/S4_SPDP/LD10HD11/QU_Pmatinv_len_10.npy
#      _get_pmati:: cached /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/Covs/S4_SPDP/LD10HD11/QU_Pmatinv_len_11.npy
#      [00:00:00]  (total [00:00:00])   get_qlms::mult with len Pmat
#      [00:00:00]  (total [00:00:00])   get_qlms::cartesian gradients
#      [00:00:00]  (total [00:00:00])   get_qlms::rotation to phi Omega
#   lensit.ffs_covs.ffs_cov   [00:00:00]  (total [00:00:00])   inverse unl Pmats  curvpOlm
#   lensit.ffs_covs.ffs_cov   [00:00:00]  (total [00:00:00])   Fxx , part 1  curvpOlm
#   lensit.ffs_covs.ffs_cov   [00:00:00]  (total [00:00:00])   Fyy , part 1  curvpOlm
#   lensit.ffs_covs.ffs_cov   [00:00:00]  (total [00:00:01])   Fxy , part 1  curvpOlm
#   lensit.ffs_covs.ffs_cov   [00:00:00]  (total [00:00:01])   Fxx , part 2  curvpOlm
#   lensit.ffs_covs.ffs_cov   [00:00:00]  (total [00:00:01])   Fyy , part 2  curvpOlm
#   lensit.ffs_covs.ffs_cov   [00:00:00]  (total [00:00:02])   Fxy , part 2  curvpOlm
#      [00:00:02]  (total [00:00:02])   get_qlm_resplm:: get curvature matrices
#      [00:00:00]  (total [00:00:02])   get_qlm_resplm:: inversion

# %% [markdown]
# ### 2. We setup the iterator instance:

# %%
from lensit.ffs_iterators.ffs_iterator_wcurl import ffs_iterator_cstMF
from lensit.misc.misc_utils import gauss_beam
from lensit.qcinv import ffs_ninv_filt_ideal, chain_samples
from lensit.ffs_covs import ell_mat
from lensit import LMAX_SKY

def get_itlib(lib_dir, POlm0, lib_qlm,  datalms, lib_datalm, H0s, beam_fwhmamin=beam, NlevT_filt=nlev_t, NlevP_filt=nlev_p):
    """
    This returns an iterator instance from the input data maps, lensing map starting point,
    likelihood curvature guess and choice of filtering parameters (ideally close to those of the data).
    """

    if not os.path.exists(lib_dir): 
        os.makedirs(lib_dir)
    # Prior on lensing power spectrum, and CMB spectra for the filtering at each iteration step.
    cls_unl = li.get_fidcls(LMAX_SKY, wrotationCls=True)[0]
    cpp_priors = [np.copy(cls_unl['pp'][:LMAX_SKY+1]), np.copy(cls_unl['oo'][:LMAX_SKY+1])]
    
    
    lib_skyalm = ell_mat.ffs_alm_pyFFTW(lib_datalm.ell_mat, filt_func=lambda ell:ell<=LMAX_SKY)
                            #: This means we perform here the lensing of CMB skies at the same resolution 
                            #  than the data with the band-limit of 6000.
    transf = gauss_beam(beam_fwhmamin / 180. / 60. * np.pi, lmax=LMAX_SKY) #: fiducial beam
    
    # Anisotropic filtering instance, with unlensed CMB spectra as inputs. Delfections will be added by the iterator.
    filt = ffs_ninv_filt_ideal.ffs_ninv_filt(lib_datalm, lib_skyalm, cls_unl, transf, NlevT_filt,NlevP_filt)
    
    # Description of the multi-grid chain to use: (here the simplest, diagonal pre-conditioner) 
    chain_descr = chain_samples.get_isomgchain(filt.lib_skyalm.ellmax,filt.lib_datalm.shape,
                                                        tol=1e-6,iter_max=200)
    
    # We assume no primordial B-modes, the E-B filtering will assume all B-modes are either noise or lensing:
    opfilt =  li.qcinv.opfilt_cinv_noBB
    opfilt._type = 'QU' # We consider polarization only
    
    # With all this now in place, we can build the iterator instance:
    iterator = ffs_iterator_cstMF(lib_dir, 'QU', filt, datalms, lib_qlm, 
              POlm0, H0s, POlm0 * 0., cpp_priors,  chain_descr=chain_descr, opfilt=opfilt, verbose=True)
               # We use here an iterator instance that uses an analytical approximation 
               # for the mean-field term at each step.
    return iterator


lib_dir = os.path.join(os.environ['LENSIT'], 'temp', 'iteratorwcurl_%s_sim%03d'%(EXP, 0))
itlib = get_itlib(lib_dir, POlm0, lib_qlm, datalms, lib_datalm, H0s)
# Out:
#  I see t 0.35355339059327373
#  I see q 0.5
#  I see u 0.5
# ffs iterator : This is 0 trying to setup /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000
# ++ ffs_QU_iterator: Caching qlm_norms and N0s/Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000
#      cached /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_P_H0.dat
#      cached /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_O_H0.dat
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/polm_it000.npy
# ++ ffs_<class 'type'> masked iterator : setup OK

# %% [markdown]
# ### 3. We perform the iterations:
# This should take about ~ 1 min. to finish. A lot of print-out in verbose mode.

# %%
itlib.soltn_cond = True
itmax = 15
for i in range(itmax + 1):
    itlib.iterate(i, 'p')
# Out:
# rank 0 caching displacement comp. for it. 5
# rank 0, ffs_deflect::buffers size, chk_shape (20, 21) [1024 1024]
# rank 0 inverting displacement it. 5
# NR iter 1: max. increment size in NR deflection inverse 1.18e+00 amin
#            mean x, y rms increment : 2.84e-02, 2.74e-02 amin
# NR iter 2: max. increment size in NR deflection inverse 1.57e-02 amin
#            mean x, y rms increment : 6.25e-05, 6.06e-05 amin
# NR iter 3: max. increment size in NR deflection inverse 1.63e-04 amin
#            mean x, y rms increment : 1.37e-07, 1.32e-07 amin
#  [00:00:00] ffs_deflect::calculating inverse displ. field > 00%
# rank 0, ffs_deflect::buffers size, chk_shape (20, 21) [1024 1024]
# almxfl, 2 comp
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpopri_it005.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpodet_it005.npy
# rank 0, ffs_deflect::buffers size, chk_shape (20, 21) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (20, 21) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it4.npy
# This is calc prep for QU W. Filtering cinv_noBB
# (1024, 5120) [00:00:01] (0, 0.0095713802)
# (1024, 5120) [00:00:01] (1, 0.0009723153)
# (1024, 5120) [00:00:02] (2, 0.0001726545)
# (1024, 5120) [00:00:02] (3, 0.0000470249)
# (1024, 5120) [00:00:03] (4, 0.0000149307)
# (1024, 5120) [00:00:04] (5, 0.0000050369)
# (1024, 5120) [00:00:04] (6, 0.0000016570)
# (1024, 5120) [00:00:05] (7, 0.0000005724)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it5.npy
# rank 0, ffs_deflect::buffers size, chk_shape (20, 21) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (20, 21) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (20, 21) [1024 1024]
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpolik_it005.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_4_po.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_0_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_0_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_1_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_1_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_2_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_2_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_3_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_3_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_4_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_4_po.npy  to Hessian
# rank 0 calculating descent direction
# almxfl, 2 comp
# almxfl, 2 comp
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_5_po.npy
#  [00:00:01]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/polm_it006.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it005_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it005_dy.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it005_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it005_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_0005_libdir
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_0005_libdir
# rank 0 caching displacement comp. for it. 6
# rank 0, ffs_deflect::buffers size, chk_shape (20, 21) [1024 1024]
# rank 0 inverting displacement it. 6
# NR iter 1: max. increment size in NR deflection inverse 1.18e+00 amin
#            mean x, y rms increment : 2.83e-02, 2.72e-02 amin
# NR iter 2: max. increment size in NR deflection inverse 1.46e-02 amin
#            mean x, y rms increment : 6.10e-05, 5.90e-05 amin
# NR iter 3: max. increment size in NR deflection inverse 9.16e-05 amin
#            mean x, y rms increment : 1.28e-07, 1.24e-07 amin
#  [00:00:00] ffs_deflect::calculating inverse displ. field > 00%
# rank 0, ffs_deflect::buffers size, chk_shape (20, 21) [1024 1024]
# almxfl, 2 comp
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpopri_it006.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpodet_it006.npy
# rank 0, ffs_deflect::buffers size, chk_shape (20, 21) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (20, 21) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it5.npy
# This is calc prep for QU W. Filtering cinv_noBB
# (1024, 5120) [00:00:01] (0, 0.0087053592)
# (1024, 5120) [00:00:01] (1, 0.0008791582)
# (1024, 5120) [00:00:02] (2, 0.0001482900)
# (1024, 5120) [00:00:03] (3, 0.0000402557)
# (1024, 5120) [00:00:03] (4, 0.0000129424)
# (1024, 5120) [00:00:04] (5, 0.0000044242)
# (1024, 5120) [00:00:04] (6, 0.0000015075)
# (1024, 5120) [00:00:05] (7, 0.0000005350)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it6.npy
# rank 0, ffs_deflect::buffers size, chk_shape (20, 21) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (20, 21) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (20, 21) [1024 1024]
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpolik_it006.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_5_po.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_0_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_0_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_1_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_1_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_2_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_2_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_3_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_3_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_4_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_4_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_5_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_5_po.npy  to Hessian
# rank 0 calculating descent direction
# almxfl, 2 comp
# almxfl, 2 comp
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_6_po.npy
#  [00:00:01]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/polm_it007.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it006_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it006_dy.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it006_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it006_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_0006_libdir
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_0006_libdir
# rank 0 caching displacement comp. for it. 7
# rank 0, ffs_deflect::buffers size, chk_shape (20, 22) [1024 1024]
# rank 0 inverting displacement it. 7
# NR iter 1: max. increment size in NR deflection inverse 1.14e+00 amin
#            mean x, y rms increment : 2.86e-02, 2.75e-02 amin
# NR iter 2: max. increment size in NR deflection inverse 1.47e-02 amin
#            mean x, y rms increment : 6.18e-05, 5.98e-05 amin
# NR iter 3: max. increment size in NR deflection inverse 8.00e-05 amin
#            mean x, y rms increment : 1.28e-07, 1.24e-07 amin
#  [00:00:00] ffs_deflect::calculating inverse displ. field > 00%
# rank 0, ffs_deflect::buffers size, chk_shape (20, 22) [1024 1024]
# almxfl, 2 comp
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpopri_it007.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpodet_it007.npy
# rank 0, ffs_deflect::buffers size, chk_shape (20, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (20, 22) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it6.npy
# This is calc prep for QU W. Filtering cinv_noBB
# (1024, 5120) [00:00:00] (0, 0.0058521079)
# (1024, 5120) [00:00:01] (1, 0.0005849342)
# (1024, 5120) [00:00:02] (2, 0.0000994096)
# (1024, 5120) [00:00:02] (3, 0.0000262633)
# (1024, 5120) [00:00:03] (4, 0.0000083892)
# (1024, 5120) [00:00:04] (5, 0.0000028699)
# (1024, 5120) [00:00:04] (6, 0.0000009712)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it7.npy
# rank 0, ffs_deflect::buffers size, chk_shape (20, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (20, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (20, 22) [1024 1024]
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpolik_it007.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_6_po.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_0_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_0_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_1_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_1_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_2_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_2_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_3_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_3_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_4_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_4_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_5_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_5_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_6_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_6_po.npy  to Hessian
# rank 0 calculating descent direction
# almxfl, 2 comp
# almxfl, 2 comp
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_7_po.npy
#  [00:00:01]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/polm_it008.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it007_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it007_dy.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it007_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it007_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_0007_libdir
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_0007_libdir
# rank 0 caching displacement comp. for it. 8
# rank 0, ffs_deflect::buffers size, chk_shape (20, 22) [1024 1024]
# rank 0 inverting displacement it. 8
# NR iter 1: max. increment size in NR deflection inverse 1.15e+00 amin
#            mean x, y rms increment : 2.91e-02, 2.80e-02 amin
# NR iter 2: max. increment size in NR deflection inverse 1.58e-02 amin
#            mean x, y rms increment : 6.37e-05, 6.16e-05 amin
# NR iter 3: max. increment size in NR deflection inverse 8.56e-05 amin
#            mean x, y rms increment : 1.32e-07, 1.28e-07 amin
#  [00:00:00] ffs_deflect::calculating inverse displ. field > 00%
# rank 0, ffs_deflect::buffers size, chk_shape (20, 22) [1024 1024]
# almxfl, 2 comp
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpopri_it008.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpodet_it008.npy
# rank 0, ffs_deflect::buffers size, chk_shape (20, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (20, 22) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it7.npy
# This is calc prep for QU W. Filtering cinv_noBB
# (1024, 5120) [00:00:00] (0, 0.0048643191)
# (1024, 5120) [00:00:01] (1, 0.0004962416)
# (1024, 5120) [00:00:02] (2, 0.0000844926)
# (1024, 5120) [00:00:02] (3, 0.0000221685)
# (1024, 5120) [00:00:03] (4, 0.0000071136)
# (1024, 5120) [00:00:03] (5, 0.0000024124)
# (1024, 5120) [00:00:04] (6, 0.0000008115)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it8.npy
# rank 0, ffs_deflect::buffers size, chk_shape (20, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (20, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (20, 22) [1024 1024]
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpolik_it008.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_7_po.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_0_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_0_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_1_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_1_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_2_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_2_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_3_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_3_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_4_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_4_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_5_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_5_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_6_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_6_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_7_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_7_po.npy  to Hessian
# rank 0 calculating descent direction
# almxfl, 2 comp
# almxfl, 2 comp
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_8_po.npy
#  [00:00:01]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/polm_it009.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it008_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it008_dy.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it008_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it008_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_0008_libdir
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_0008_libdir
# rank 0 caching displacement comp. for it. 9
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0 inverting displacement it. 9
# NR iter 1: max. increment size in NR deflection inverse 1.19e+00 amin
#            mean x, y rms increment : 2.96e-02, 2.85e-02 amin
# NR iter 2: max. increment size in NR deflection inverse 1.68e-02 amin
#            mean x, y rms increment : 6.56e-05, 6.35e-05 amin
# NR iter 3: max. increment size in NR deflection inverse 9.14e-05 amin
#            mean x, y rms increment : 1.36e-07, 1.32e-07 amin
#  [00:00:00] ffs_deflect::calculating inverse displ. field > 00%
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# almxfl, 2 comp
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpopri_it009.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpodet_it009.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it8.npy
# This is calc prep for QU W. Filtering cinv_noBB
# (1024, 5120) [00:00:00] (0, 0.0052355090)
# (1024, 5120) [00:00:01] (1, 0.0005227634)
# (1024, 5120) [00:00:02] (2, 0.0000866531)
# (1024, 5120) [00:00:02] (3, 0.0000228284)
# (1024, 5120) [00:00:03] (4, 0.0000074249)
# (1024, 5120) [00:00:04] (5, 0.0000025959)
# (1024, 5120) [00:00:04] (6, 0.0000008965)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it9.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpolik_it009.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_8_po.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_0_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_0_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_1_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_1_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_2_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_2_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_3_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_3_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_4_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_4_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_5_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_5_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_6_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_6_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_7_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_7_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_8_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_8_po.npy  to Hessian
# rank 0 calculating descent direction
# almxfl, 2 comp
# almxfl, 2 comp
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_9_po.npy
#  [00:00:01]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/polm_it010.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it009_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it009_dy.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it009_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it009_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_0009_libdir
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_0009_libdir
# rank 0 caching displacement comp. for it. 10
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0 inverting displacement it. 10
# NR iter 1: max. increment size in NR deflection inverse 1.22e+00 amin
#            mean x, y rms increment : 3.00e-02, 2.89e-02 amin
# NR iter 2: max. increment size in NR deflection inverse 1.71e-02 amin
#            mean x, y rms increment : 6.69e-05, 6.46e-05 amin
# NR iter 3: max. increment size in NR deflection inverse 9.26e-05 amin
#            mean x, y rms increment : 1.38e-07, 1.34e-07 amin
#  [00:00:00] ffs_deflect::calculating inverse displ. field > 00%
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# almxfl, 2 comp
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpopri_it010.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpodet_it010.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it9.npy
# This is calc prep for QU W. Filtering cinv_noBB
# (1024, 5120) [00:00:00] (0, 0.0044314909)
# (1024, 5120) [00:00:01] (1, 0.0004459392)
# (1024, 5120) [00:00:02] (2, 0.0000745972)
# (1024, 5120) [00:00:02] (3, 0.0000197750)
# (1024, 5120) [00:00:03] (4, 0.0000065581)
# (1024, 5120) [00:00:04] (5, 0.0000023459)
# (1024, 5120) [00:00:04] (6, 0.0000008208)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it10.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpolik_it010.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_9_po.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_0_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_0_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_1_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_1_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_2_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_2_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_3_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_3_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_4_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_4_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_5_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_5_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_6_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_6_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_7_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_7_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_8_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_8_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_9_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_9_po.npy  to Hessian
# rank 0 calculating descent direction
# almxfl, 2 comp
# almxfl, 2 comp
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_10_po.npy
#  [00:00:01]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/polm_it011.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it010_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it010_dy.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it010_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it010_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_0010_libdir
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_0010_libdir
# rank 0 caching displacement comp. for it. 11
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0 inverting displacement it. 11
# NR iter 1: max. increment size in NR deflection inverse 1.23e+00 amin
#            mean x, y rms increment : 3.04e-02, 2.92e-02 amin
# NR iter 2: max. increment size in NR deflection inverse 1.72e-02 amin
#            mean x, y rms increment : 6.78e-05, 6.55e-05 amin
# NR iter 3: max. increment size in NR deflection inverse 9.37e-05 amin
#            mean x, y rms increment : 1.39e-07, 1.34e-07 amin
#  [00:00:01] ffs_deflect::calculating inverse displ. field > 00%
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# almxfl, 2 comp
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpopri_it011.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpodet_it011.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it10.npy
# This is calc prep for QU W. Filtering cinv_noBB
# (1024, 5120) [00:00:00] (0, 0.0043028434)
# (1024, 5120) [00:00:01] (1, 0.0004375614)
# (1024, 5120) [00:00:02] (2, 0.0000729218)
# (1024, 5120) [00:00:03] (3, 0.0000188345)
# (1024, 5120) [00:00:04] (4, 0.0000061745)
# (1024, 5120) [00:00:04] (5, 0.0000021912)
# (1024, 5120) [00:00:05] (6, 0.0000007585)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it11.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpolik_it011.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_10_po.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_0_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_0_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_1_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_1_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_2_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_2_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_3_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_3_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_4_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_4_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_5_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_5_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_6_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_6_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_7_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_7_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_8_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_8_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_9_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_9_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_10_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_10_po.npy  to Hessian
# rank 0 calculating descent direction
# almxfl, 2 comp
# almxfl, 2 comp
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_11_po.npy
#  [00:00:02]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/polm_it012.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it011_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it011_dy.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it011_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it011_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_0011_libdir
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_0011_libdir
# rank 0 caching displacement comp. for it. 12
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0 inverting displacement it. 12
# NR iter 1: max. increment size in NR deflection inverse 1.23e+00 amin
#            mean x, y rms increment : 3.08e-02, 2.95e-02 amin
# NR iter 2: max. increment size in NR deflection inverse 1.77e-02 amin
#            mean x, y rms increment : 6.89e-05, 6.64e-05 amin
# NR iter 3: max. increment size in NR deflection inverse 9.67e-05 amin
#            mean x, y rms increment : 1.40e-07, 1.35e-07 amin
#  [00:00:00] ffs_deflect::calculating inverse displ. field > 00%
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# almxfl, 2 comp
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpopri_it012.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpodet_it012.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it11.npy
# This is calc prep for QU W. Filtering cinv_noBB
# (1024, 5120) [00:00:00] (0, 0.0047488887)
# (1024, 5120) [00:00:01] (1, 0.0004847463)
# (1024, 5120) [00:00:02] (2, 0.0000801758)
# (1024, 5120) [00:00:02] (3, 0.0000204146)
# (1024, 5120) [00:00:03] (4, 0.0000067034)
# (1024, 5120) [00:00:04] (5, 0.0000023759)
# (1024, 5120) [00:00:04] (6, 0.0000008215)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it12.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 22) [1024 1024]
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpolik_it012.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_11_po.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_0_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_0_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_1_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_1_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_2_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_2_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_3_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_3_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_4_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_4_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_5_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_5_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_6_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_6_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_7_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_7_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_8_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_8_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_9_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_9_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_10_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_10_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_11_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_11_po.npy  to Hessian
# rank 0 calculating descent direction
# almxfl, 2 comp
# almxfl, 2 comp
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_12_po.npy
#  [00:00:02]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/polm_it013.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it012_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it012_dy.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it012_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it012_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_0012_libdir
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_0012_libdir
# rank 0 caching displacement comp. for it. 13
# rank 0, ffs_deflect::buffers size, chk_shape (21, 23) [1024 1024]
# rank 0 inverting displacement it. 13
# NR iter 1: max. increment size in NR deflection inverse 1.24e+00 amin
#            mean x, y rms increment : 3.11e-02, 2.98e-02 amin
# NR iter 2: max. increment size in NR deflection inverse 1.84e-02 amin
#            mean x, y rms increment : 6.99e-05, 6.74e-05 amin
# NR iter 3: max. increment size in NR deflection inverse 1.00e-04 amin
#            mean x, y rms increment : 1.41e-07, 1.36e-07 amin
#  [00:00:01] ffs_deflect::calculating inverse displ. field > 00%
# rank 0, ffs_deflect::buffers size, chk_shape (21, 23) [1024 1024]
# almxfl, 2 comp
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpopri_it013.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpodet_it013.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 23) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 23) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it12.npy
# This is calc prep for QU W. Filtering cinv_noBB
# (1024, 5120) [00:00:01] (0, 0.0037303156)
# (1024, 5120) [00:00:01] (1, 0.0003838162)
# (1024, 5120) [00:00:02] (2, 0.0000636987)
# (1024, 5120) [00:00:02] (3, 0.0000162271)
# (1024, 5120) [00:00:03] (4, 0.0000053410)
# (1024, 5120) [00:00:04] (5, 0.0000019030)
# (1024, 5120) [00:00:04] (6, 0.0000006573)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it13.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 23) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 23) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 23) [1024 1024]
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpolik_it013.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_12_po.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_0_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_0_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_1_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_1_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_2_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_2_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_3_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_3_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_4_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_4_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_5_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_5_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_6_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_6_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_7_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_7_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_8_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_8_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_9_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_9_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_10_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_10_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_11_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_11_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_12_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_12_po.npy  to Hessian
# rank 0 calculating descent direction
# almxfl, 2 comp
# almxfl, 2 comp
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_13_po.npy
#  [00:00:02]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/polm_it014.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it013_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it013_dy.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it013_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it013_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_0013_libdir
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_0013_libdir
# rank 0 caching displacement comp. for it. 14
# rank 0, ffs_deflect::buffers size, chk_shape (21, 23) [1024 1024]
# rank 0 inverting displacement it. 14
# NR iter 1: max. increment size in NR deflection inverse 1.25e+00 amin
#            mean x, y rms increment : 3.13e-02, 3.00e-02 amin
# NR iter 2: max. increment size in NR deflection inverse 1.90e-02 amin
#            mean x, y rms increment : 7.06e-05, 6.80e-05 amin
# NR iter 3: max. increment size in NR deflection inverse 1.02e-04 amin
#            mean x, y rms increment : 1.43e-07, 1.37e-07 amin
#  [00:00:00] ffs_deflect::calculating inverse displ. field > 00%
# rank 0, ffs_deflect::buffers size, chk_shape (21, 23) [1024 1024]
# almxfl, 2 comp
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpopri_it014.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpodet_it014.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 23) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 23) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it13.npy
# This is calc prep for QU W. Filtering cinv_noBB
# (1024, 5120) [00:00:01] (0, 0.0020047042)
# (1024, 5120) [00:00:01] (1, 0.0002054289)
# (1024, 5120) [00:00:02] (2, 0.0000343615)
# (1024, 5120) [00:00:02] (3, 0.0000088461)
# (1024, 5120) [00:00:03] (4, 0.0000029251)
# (1024, 5120) [00:00:04] (5, 0.0000010419)
# (1024, 5120) [00:00:04] (6, 0.0000003628)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/MAPlms/Mlik_po_it14.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 23) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 23) [1024 1024]
# rank 0, ffs_deflect::buffers size, chk_shape (21, 23) [1024 1024]
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/qlm_gradpolik_it014.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_13_po.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_0_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_0_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_1_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_1_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_2_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_2_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_3_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_3_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_4_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_4_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_5_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_5_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_6_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_6_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_7_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_7_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_8_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_8_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_9_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_9_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_10_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_10_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_11_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_11_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_12_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_12_po.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_yn_13_po.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_13_po.npy  to Hessian
# rank 0 calculating descent direction
# almxfl, 2 comp
# almxfl, 2 comp
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/Hessian/rlm_sn_14_po.npy
#  [00:00:02]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/polm_it015.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it014_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_po_it014_dy.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it014_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_po_it014_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/f_0014_libdir
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iteratorwcurl_S4_SPDP_sim000/finv_0014_libdir

# %% [markdown]
# ### 4. We have a quick look at the quality of the lensing map reconstruction:
# We plot the binned power spectrum of the residual map
# $$
# \hat \phi - \phi^{\rm input}
# $$

# %%
ell, = np.where(itlib.lib_qlm.get_Nell()[:3001])
w = lambda ell : ell ** 2 * (ell + 1.) ** 2 /2./np.pi * 1e7
edges = np.arange(0, 3100, 100)
bl = edges[:-1];bu = edges[1:] 

sims = li.get_maps_lib(EXP, 11, 11, wrotation=True, nsims=1)
plm_input = itlib.lib_qlm.udgrade(sims.lencmbs.lib_skyalm, sims.lencmbs.get_sim_plm(0))
olm_input = itlib.lib_qlm.udgrade(sims.lencmbs.lib_skyalm, sims.lencmbs.get_sim_olm(0))
s = itlib.lib_qlm.alm_size
bnd_cl = lambda cl : li.misc.misc_utils.binned(cl, ell, bl, bu, w=w, return_err=True)
pl.figure(figsize= (10,5))
for it in range(itmax + 1):
    cl, err = bnd_cl(itlib.lib_qlm.alm2cl(itlib.get_POlm(it)[0:s] - plm_input)) 
    pl.errorbar(0.5 * bl + 0.5 * bu, cl, yerr=err, label='Iter. %s'%it + (it == 0) * ' (Q.E.)')
pl.plot(ell, li.get_fidcls()[0]['pp'][ell] * w(ell), c='k', label=r'$C_L^{\phi\phi, \rm fid}$')
pl.ylabel(r'$10^7\: L^2(L + 1)^2 C^{\hat \phi - \phi^{\rm in}}_L /2 \pi$', fontsize=20)
pl.xlabel(r'$L$', fontsize=14)
pl.legend(ncol=3, fontsize=14)
pl.semilogy()
pl.figure(figsize= (10,5))
for it in range(itmax + 1):
    cl, err = bnd_cl(itlib.lib_qlm.alm2cl(itlib.get_POlm(it)[s:2*s] - olm_input)) 
    pl.errorbar(0.5 * bl + 0.5 * bu, cl, yerr=err, label='Iter. %s'%it + (it == 0) * ' (Q.E.)')
pl.plot(ell, li.get_fidcls(wrotationCls=True)[0]['oo'][ell] * w(ell), c='k', label=r'$C_L^{\Omega \Omega, \rm fid}$')
pl.ylabel(r'$10^7\: L^2(L + 1)^2 C^{\hat \phi - \phi^{\rm in}}_L /2 \pi$', fontsize=20)
pl.xlabel(r'$L$', fontsize=14)
pl.legend(ncol=3, fontsize=14)
pl.semilogy()
# Out:
# []

# %%
from lensit.misc.misc_utils import binned

coo_fid = li.get_fidcls(wrotationCls=True)[0]['oo']
s = lib_qlm.alm_size
bls = 50 * np.arange(40)
bus = 50 * np.arange(1, 41)
bcs = 0.5 * (bls + bus)
clx = np.zeros(lib_qlm.ellmax + 1)
ls, = np.where(lib_qlm.get_Nell()[:3001]> 1)

for it in np.unique([0, itmax // 2, itmax]):
    olm = itlib.get_POlm(it)[s:2*s]
    clx[ls] = lib_qlm.alm2cl(olm, olm_input)[ls] /(np.sqrt(coo_fid[ls] * lib_qlm.alm2cl(olm)[ls]))
    #pl.plot(ls, clx[ls])
    pl.plot(bcs, binned(clx, ls, bls, bus), label='iter ' + str(it))
pl.legend()
pl.title('cross-correlation to curl')
# Out:
# Text(0.5, 1.0, 'cross-correlation to curl')
