# %% [markdown]
# # Iterative lensing estimation demo (CMB-S4).
#
# This notebook goes through an example of lensing iterative reconstruction, from polarization Q and U CMB data, with noise level of 2.12 $\mu$K-arcmin, on 650 square degrees, under ideal conditions (no masking, homogeneous noise, etc), with pixel size 1.5 arcmin. Specifically, we proceed as follows
# 1. We build the quadratic estimator and initial curvature estimates
# 2. We setup the iterator instance
# 3. We perform the iterations
# 4. We have a quick look at the quality of the lensing map reconstruction
#
# It should take or minute or so to perform all iterations from the starting point.
#
# Before starting, set the environment variable LENSIT to somewhere that is safe to write. A bunch of stuff might get cached.

# %%
# %matplotlib inline
import pylab as pl
import numpy as np
import lensit as li
import os

# %% [markdown]
# ### 1. We build the quadratic estimator and initial curvature estimates:

# %%
def get_starting_point(idx): 
    """
    This returns initial data for simulation index 'idx' from a CMB-S4 simulation library.
    On first call the simulation library will generate all simulations phases, hence might take a little while.
    """ 
    sims = li.get_maps_lib('S4', 10, 11) # Simulation-library for configuration 'S4'. 
                                         # Parameters 10, 11 produces data on 645 sq. deg, 
                                         # with lensed CMB's generated at 0.75 arcmin resolution, 
                                         # but data collected at 1.5 arcmin resolution. 
    
    isocov = li.get_isocov('S4', 10, 11) # Isotropic filtering instance, that can used for Q.E. calculation
                                         # and other things.isocov.lib_datalm defines the mode-filtering applied 
                                         # the data, and isocov.lib_skyalm the band-limits of the unlensed sky.
    print(" I will be using data from ell=%s to ell=%s only"%(isocov.lib_datalm.ellmin, isocov.lib_datalm.ellmax))
    print(" The sky band-limit is ell=%s"%(isocov.lib_skyalm.ellmax))
    
    lib_qlm = isocov.lib_skyalm #: This means we will reconstruct the lensing potential for all unlensed sky modes.
    def cli(cl):
        ret = np.zeros_like(cl)
        ret[np.where(cl > 0)] = 1./cl[np.where(cl > 0)]
        return ret
    
    # We now build the Wiener-filtered quadratic estimator. We use lensed CMB spectra in the weights.
    datalms = np.array([isocov.lib_datalm.map2alm(m) for m in sims.get_sim_qumap(idx)]) 
    H0len =  cli(isocov.get_N0cls('QU', lib_qlm, use_cls_len=True)[0])
    plm0 = 0.5 * isocov.get_qlms('QU',  isocov.get_iblms('QU', datalms, use_cls_len=True)[0], lib_qlm, 
                                 use_cls_len=True)[0]
    
    # Normalization and Wiener-filtering:
    cpp_prior = li.get_fidcls()[0]['pp'][:lib_qlm.ellmax+1]
    lib_qlm.almxfl(plm0, cli(H0len + cli(cpp_prior)), inplace=True)
    
    # Initial likelihood curvature guess. We use here N0 as calculated with unlensed CMB spectra:
    H0unl =  cli(isocov.get_N0cls('QU', lib_qlm, use_cls_len=False)[0])
    return plm0, lib_qlm, datalms, isocov.lib_datalm, H0unl, H0len

plm0, lib_qlm, datalms, lib_datalm, H0, H0len = get_starting_point(0)
# Out:
#  I will be using data from ell=14 to ell=3000 only
#  The sky band-limit is ell=5120
#      [00:00:00]  (total [00:00:00])   get_qlms::mult with len Pmat
#      [00:00:00]  (total [00:00:00])   get_qlms::cartesian gradients
#      [00:00:00]  (total [00:00:00])   get_qlms::rotation to phi Omega

# %% [markdown]
# ### 2. We setup the iterator instance:

# %%
from lensit.ffs_iterators.ffs_iterator_nufft import ffs_iterator_cstMF
from lensit.misc.misc_utils import gauss_beam
from lensit.qcinv import ffs_ninv_filt_ideal_nufft as ffs_ninv_filt_ideal, chain_samples
from lensit.ffs_covs import ell_mat
from lensit.ffs_deflect import ffs_deflect

def get_itlib(lib_dir, plm0, lib_qlm,  datalms, lib_datalm, H0, beam_fwhmamin=3., NlevT_filt=1.5, NlevP_filt=1.5 * np.sqrt(2.), nufft_epsilon=1e-7):
    """
    This returns an iterator instance from the input data maps, lensing map starting point,
    likelihood curvature guess and choice of filtering parameters (ideally close to those of the data).
    """

    if not os.path.exists(lib_dir): 
        os.makedirs(lib_dir)
    # Prior on lensing power spectrum, and CMB spectra for the filtering at each iteration step.
    cls_unl = li.get_fidcls(6000)[0]
    cpp_prior = cls_unl['pp'][:]
    
    
    lib_skyalm = ell_mat.ffs_alm_pyFFTW(lib_datalm.ell_mat, filt_func=lambda ell:ell<=6000)
                            #: This means we perform here the lensing of CMB skies at the same resolution 
                            #  than the data with the band-limit of 6000.
    transf = gauss_beam(beam_fwhmamin / 180. / 60. * np.pi, lmax=6000) #: fiducial beam
    
    # Anisotropic filtering instance, with unlensed CMB spectra as inputs. Delfections will be added by the iterator.
    f_id = ffs_deflect.ffs_id_displacement(lib_skyalm.shape, lib_skyalm.lsides)
    filt = ffs_ninv_filt_ideal.ffs_ninv_filt_wl(lib_datalm, lib_skyalm, cls_unl, transf, NlevT_filt,NlevP_filt, f=f_id)
    
    # Description of the multi-grid chain to use: (here the simplest, diagonal pre-conditioner) 
    chain_descr = chain_samples.get_isomgchain(filt.lib_skyalm.ellmax,filt.lib_datalm.shape,
                                                        tol=1e-6,iter_max=200)
    
    # We assume no primordial B-modes, the E-B filtering will assume all B-modes are either noise or lensing:
    opfilt =  li.qcinv.opfilt_cinv_noBB
    opfilt._type = 'QU' # We consider polarization only
    
    # With all this now in place, we can build the iterator instance:
    iterator = ffs_iterator_cstMF(lib_dir, 'QU', filt, datalms, lib_qlm, 
              plm0, H0, plm0 * 0, cpp_prior, chain_descr=chain_descr, opfilt=opfilt, verbose=True, nufft_epsilon=1e-7)
               # We use here an iterator instance that uses an analytical approximation 
               # for the mean-field term at each step.
    return iterator


lib_dir = os.path.join(os.environ['LENSIT'], 'temp', 'iterator_S4_sim%03d'%0)
itlib = get_itlib(lib_dir, plm0, lib_qlm, datalms, lib_datalm, H0)
# Out:
#  I see t 1.5
#  I see q 2.121320343559643
#  I see u 2.121320343559643
# ffs iterator : This is 0 trying to setup /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000
# ++ ffs_<class 'type'> masked iterator : setup OK

# %% [markdown]
# ### 3. We perform the iterations:
# This should take about ~ 1 min. to finish. A lot of print-out in verbose mode.

# %%
itlib.soltn_cond = True
for i in range(10):
    itlib.iterate(i, 'p')
# Out:
# rank 0 caching displacement comp. for it. 0 for key p
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPpri_it000.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPdet_it000.npy
# rank 0, ffs_deflect::buffers size, chk_shape (22, 29) [1024 1024]
# This is calc prep for QU W. Filtering cinv_noBB
# Building nufft bwd plan
# Building nufft fwd plan
# (1024, 6000) [00:00:01] (0, 1.0000000000)
# (1024, 6000) [00:00:01] (1, 0.0792511963)
# (1024, 6000) [00:00:02] (2, 0.0110521763)
# (1024, 6000) [00:00:02] (3, 0.0021091491)
# (1024, 6000) [00:00:03] (4, 0.0004707779)
# (1024, 6000) [00:00:04] (5, 0.0001160116)
# (1024, 6000) [00:00:04] (6, 0.0000296567)
# (1024, 6000) [00:00:05] (7, 0.0000077098)
# (1024, 6000) [00:00:06] (8, 0.0000020993)
# (1024, 6000) [00:00:06] (9, 0.0000005869)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it0.npy
# rank 0, ffs_deflect::buffers size, chk_shape (22, 29) [1024 1024]
# Building nufft fwd plan
# rank 0, ffs_deflect::buffers size, chk_shape (22, 29) [1024 1024]
# Building nufft fwd plan
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPlik_it000.npy
# rank 0 calculating descent direction
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_0_p.npy
#  [00:00:00]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Phi_plm_it001.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it000_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it000_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_0000_libdir
# rank 0 caching displacement comp. for it. 1 for key p
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPpri_it001.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPdet_it001.npy
# rank 0, ffs_deflect::buffers size, chk_shape (19, 26) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it0.npy
# This is calc prep for QU W. Filtering cinv_noBB
# Building nufft bwd plan
# Building nufft fwd plan
# (1024, 6000) [00:00:01] (0, 0.0793013242)
# (1024, 6000) [00:00:01] (1, 0.0066775545)
# (1024, 6000) [00:00:02] (2, 0.0009342812)
# (1024, 6000) [00:00:02] (3, 0.0001726375)
# (1024, 6000) [00:00:03] (4, 0.0000365567)
# (1024, 6000) [00:00:04] (5, 0.0000077834)
# (1024, 6000) [00:00:04] (6, 0.0000016173)
# (1024, 6000) [00:00:05] (7, 0.0000003558)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it1.npy
# rank 0, ffs_deflect::buffers size, chk_shape (19, 26) [1024 1024]
# Building nufft fwd plan
# rank 0, ffs_deflect::buffers size, chk_shape (19, 26) [1024 1024]
# Building nufft fwd plan
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPlik_it001.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_0_p.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_0_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_0_p.npy  to Hessian
# rank 0 calculating descent direction
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_1_p.npy
#  [00:00:00]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Phi_plm_it002.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it001_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it001_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_0001_libdir
# rank 0 caching displacement comp. for it. 2 for key p
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPpri_it002.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPdet_it002.npy
# rank 0, ffs_deflect::buffers size, chk_shape (19, 26) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it1.npy
# This is calc prep for QU W. Filtering cinv_noBB
# Building nufft bwd plan
# Building nufft fwd plan
# (1024, 6000) [00:00:01] (0, 0.0162086373)
# (1024, 6000) [00:00:01] (1, 0.0014764396)
# (1024, 6000) [00:00:02] (2, 0.0002167819)
# (1024, 6000) [00:00:03] (3, 0.0000407228)
# (1024, 6000) [00:00:04] (4, 0.0000084101)
# (1024, 6000) [00:00:04] (5, 0.0000018111)
# (1024, 6000) [00:00:05] (6, 0.0000004103)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it2.npy
# rank 0, ffs_deflect::buffers size, chk_shape (19, 26) [1024 1024]
# Building nufft fwd plan
# rank 0, ffs_deflect::buffers size, chk_shape (19, 26) [1024 1024]
# Building nufft fwd plan
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPlik_it002.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_1_p.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_0_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_0_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_1_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_1_p.npy  to Hessian
# rank 0 calculating descent direction
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_2_p.npy
#  [00:00:00]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Phi_plm_it003.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it002_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it002_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_0002_libdir
# rank 0 caching displacement comp. for it. 3 for key p
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPpri_it003.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPdet_it003.npy
# rank 0, ffs_deflect::buffers size, chk_shape (20, 27) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it2.npy
# This is calc prep for QU W. Filtering cinv_noBB
# Building nufft bwd plan
# Building nufft fwd plan
# (1024, 6000) [00:00:01] (0, 0.0175112236)
# (1024, 6000) [00:00:01] (1, 0.0015653303)
# (1024, 6000) [00:00:02] (2, 0.0002249356)
# (1024, 6000) [00:00:03] (3, 0.0000423645)
# (1024, 6000) [00:00:04] (4, 0.0000094094)
# (1024, 6000) [00:00:04] (5, 0.0000022709)
# (1024, 6000) [00:00:05] (6, 0.0000005631)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it3.npy
# rank 0, ffs_deflect::buffers size, chk_shape (20, 27) [1024 1024]
# Building nufft fwd plan
# rank 0, ffs_deflect::buffers size, chk_shape (20, 27) [1024 1024]
# Building nufft fwd plan
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPlik_it003.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_2_p.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_0_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_0_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_1_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_1_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_2_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_2_p.npy  to Hessian
# rank 0 calculating descent direction
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_3_p.npy
#  [00:00:00]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Phi_plm_it004.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it003_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it003_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_0003_libdir
# rank 0 caching displacement comp. for it. 4 for key p
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPpri_it004.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPdet_it004.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 28) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it3.npy
# This is calc prep for QU W. Filtering cinv_noBB
# Building nufft bwd plan
# Building nufft fwd plan
# (1024, 6000) [00:00:01] (0, 0.0097249783)
# (1024, 6000) [00:00:01] (1, 0.0009070739)
# (1024, 6000) [00:00:02] (2, 0.0001340393)
# (1024, 6000) [00:00:03] (3, 0.0000255631)
# (1024, 6000) [00:00:04] (4, 0.0000057552)
# (1024, 6000) [00:00:04] (5, 0.0000014140)
# (1024, 6000) [00:00:05] (6, 0.0000003504)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it4.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 28) [1024 1024]
# Building nufft fwd plan
# rank 0, ffs_deflect::buffers size, chk_shape (21, 28) [1024 1024]
# Building nufft fwd plan
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPlik_it004.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_3_p.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_0_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_0_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_1_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_1_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_2_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_2_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_3_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_3_p.npy  to Hessian
# rank 0 calculating descent direction
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_4_p.npy
#  [00:00:00]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Phi_plm_it005.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it004_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it004_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_0004_libdir
# rank 0 caching displacement comp. for it. 5 for key p
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPpri_it005.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPdet_it005.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 28) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it4.npy
# This is calc prep for QU W. Filtering cinv_noBB
# Building nufft bwd plan
# Building nufft fwd plan
# (1024, 6000) [00:00:01] (0, 0.0055554709)
# (1024, 6000) [00:00:01] (1, 0.0005242463)
# (1024, 6000) [00:00:02] (2, 0.0000785879)
# (1024, 6000) [00:00:03] (3, 0.0000150854)
# (1024, 6000) [00:00:04] (4, 0.0000034038)
# (1024, 6000) [00:00:04] (5, 0.0000008303)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it5.npy
# rank 0, ffs_deflect::buffers size, chk_shape (21, 28) [1024 1024]
# Building nufft fwd plan
# rank 0, ffs_deflect::buffers size, chk_shape (21, 28) [1024 1024]
# Building nufft fwd plan
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPlik_it005.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_4_p.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_0_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_0_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_1_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_1_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_2_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_2_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_3_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_3_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_4_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_4_p.npy  to Hessian
# rank 0 calculating descent direction
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_5_p.npy
#  [00:00:00]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Phi_plm_it006.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it005_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it005_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_0005_libdir
# rank 0 caching displacement comp. for it. 6 for key p
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPpri_it006.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPdet_it006.npy
# rank 0, ffs_deflect::buffers size, chk_shape (22, 29) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it5.npy
# This is calc prep for QU W. Filtering cinv_noBB
# Building nufft bwd plan
# Building nufft fwd plan
# (1024, 6000) [00:00:01] (0, 0.0046736915)
# (1024, 6000) [00:00:01] (1, 0.0004412059)
# (1024, 6000) [00:00:02] (2, 0.0000661378)
# (1024, 6000) [00:00:03] (3, 0.0000127697)
# (1024, 6000) [00:00:03] (4, 0.0000028998)
# (1024, 6000) [00:00:04] (5, 0.0000007130)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it6.npy
# rank 0, ffs_deflect::buffers size, chk_shape (22, 29) [1024 1024]
# Building nufft fwd plan
# rank 0, ffs_deflect::buffers size, chk_shape (22, 29) [1024 1024]
# Building nufft fwd plan
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPlik_it006.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_5_p.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_0_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_0_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_1_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_1_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_2_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_2_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_3_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_3_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_4_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_4_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_5_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_5_p.npy  to Hessian
# rank 0 calculating descent direction
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_6_p.npy
#  [00:00:01]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Phi_plm_it007.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it006_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it006_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_0006_libdir
# rank 0 caching displacement comp. for it. 7 for key p
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPpri_it007.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPdet_it007.npy
# rank 0, ffs_deflect::buffers size, chk_shape (22, 29) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it6.npy
# This is calc prep for QU W. Filtering cinv_noBB
# Building nufft bwd plan
# Building nufft fwd plan
# (1024, 6000) [00:00:01] (0, 0.0031005013)
# (1024, 6000) [00:00:01] (1, 0.0002910820)
# (1024, 6000) [00:00:02] (2, 0.0000440431)
# (1024, 6000) [00:00:03] (3, 0.0000085749)
# (1024, 6000) [00:00:03] (4, 0.0000019452)
# (1024, 6000) [00:00:04] (5, 0.0000004757)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it7.npy
# rank 0, ffs_deflect::buffers size, chk_shape (22, 29) [1024 1024]
# Building nufft fwd plan
# rank 0, ffs_deflect::buffers size, chk_shape (22, 29) [1024 1024]
# Building nufft fwd plan
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPlik_it007.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_6_p.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_0_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_0_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_1_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_1_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_2_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_2_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_3_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_3_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_4_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_4_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_5_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_5_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_6_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_6_p.npy  to Hessian
# rank 0 calculating descent direction
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_7_p.npy
#  [00:00:01]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Phi_plm_it008.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it007_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it007_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_0007_libdir
# rank 0 caching displacement comp. for it. 8 for key p
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPpri_it008.npy
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPdet_it008.npy
# rank 0, ffs_deflect::buffers size, chk_shape (22, 29) [1024 1024]
# rank 0 loading /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it7.npy
# This is calc prep for QU W. Filtering cinv_noBB
# Building nufft bwd plan
# Building nufft fwd plan
# (1024, 6000) [00:00:01] (0, 0.0012921147)
# (1024, 6000) [00:00:01] (1, 0.0001219467)
# (1024, 6000) [00:00:02] (2, 0.0000183717)
# (1024, 6000) [00:00:03] (3, 0.0000035209)
# (1024, 6000) [00:00:03] (4, 0.0000007916)
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/MAPlms/Mlik_p_it8.npy
# rank 0, ffs_deflect::buffers size, chk_shape (22, 29) [1024 1024]
# Building nufft fwd plan
# rank 0, ffs_deflect::buffers size, chk_shape (22, 29) [1024 1024]
# Building nufft fwd plan
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/qlm_gradPlik_it008.npy
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_7_p.npy
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_0_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_0_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_1_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_1_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_2_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_2_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_3_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_3_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_4_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_4_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_5_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_5_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_6_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_6_p.npy  to Hessian
# Linked y vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_yn_7_p.npy  to Hessian
# Linked s vector  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_7_p.npy  to Hessian
# rank 0 calculating descent direction
# rank 0 caching  /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Hessian/rlm_sn_8_p.npy
#  [00:00:01]  Exec. time for descent direction calculation
# rank 0 caching /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/Phi_plm_it009.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it008_dx.npy
#      removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_p_it008_dy.npy
# Removed : /Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/iterator_S4_sim000/f_0008_libdir

# %% [markdown]
# ### 4. We have a quick look at the quality of the lensing map reconstruction:
# We plot the binned power spectrum of the residual map
# $$
# \hat \phi - \phi^{\rm input}
# $$

# %%
ell, = np.where(itlib.lib_qlm.get_Nell()[:3001])
w = lambda ell : ell ** 2 * (ell + 1.) ** 2 /2./np.pi * 1e7
edges = np.arange(0, 3100, 100)
bl = edges[:-1];bu = edges[1:] 

sims = li.get_maps_lib('S4', 10, 11)
plm_input = itlib.lib_qlm.udgrade(sims.lencmbs.lib_skyalm, sims.lencmbs.get_sim_plm(0))
bnd_cl = lambda cl : li.misc.misc_utils.binned(cl, ell, bl, bu, w=w, return_err=True)
pl.figure(figsize= (10,5))
for it in [0, 1, 9]:
    cl, err = bnd_cl(itlib.lib_qlm.alm2cl(itlib.get_Plm(it, 'p') - plm_input)) 
    pl.errorbar(0.5 * bl + 0.5 * bu, cl, yerr=err, label='Iter. %s'%it + (it == 0) * ' (Q.E.)')
pl.plot(ell, li.get_fidcls()[0]['pp'][ell] * w(ell), c='k', label=r'$C_L^{\phi\phi, \rm fid}$')
pl.ylabel(r'$10^7\: L^2(L + 1)^2 C^{\hat \phi - \phi^{\rm in}}_L /2 \pi$', fontsize=20)
pl.xlabel(r'$L$', fontsize=14)
pl.legend(ncol=3, fontsize=14)
pl.semilogy()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/ipykernel/ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /Users/jcarron/Library/CloudStorage/OneDrive-unige.ch/LensIt/lensit/ffs_covs/ell_mat.py:49: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/ellmats/ellmat_11_11/ellmat_hash.pk'>
#   hash_check(pk.load(open(fn_hash, 'rb')), self.hash_dict())
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /Users/jcarron/Library/CloudStorage/OneDrive-unige.ch/LensIt/lensit/sims/sims_generic.py:96: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/120_sims/fsky0016/len_alms/skypha/ffs_pha_0000/sim_hash.pk'>
#   hash_check(pk.load(open(fn, 'rb')), self.hashdict(), ignore=['lib_dir'])
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /Users/jcarron/Library/CloudStorage/OneDrive-unige.ch/LensIt/lensit/sims/sims_generic.py:96: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/120_sims/fsky0016/len_alms/skypha/ffs_pha_0001/sim_hash.pk'>
#   hash_check(pk.load(open(fn, 'rb')), self.hashdict(), ignore=['lib_dir'])
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /Users/jcarron/Library/CloudStorage/OneDrive-unige.ch/LensIt/lensit/sims/sims_generic.py:96: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/120_sims/fsky0016/len_alms/skypha/ffs_pha_0002/sim_hash.pk'>
#   hash_check(pk.load(open(fn, 'rb')), self.hashdict(), ignore=['lib_dir'])
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /Users/jcarron/Library/CloudStorage/OneDrive-unige.ch/LensIt/lensit/sims/sims_generic.py:96: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/120_sims/fsky0016/len_alms/skypha/ffs_pha_0003/sim_hash.pk'>
#   hash_check(pk.load(open(fn, 'rb')), self.hashdict(), ignore=['lib_dir'])
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /Users/jcarron/Library/CloudStorage/OneDrive-unige.ch/LensIt/lensit/sims/ffs_cmbs.py:124: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/120_sims/fsky0016/len_alms/sim_hash.pk'>
#   sims_generic.hash_check(self.hashdict(), pk.load(open(fn_hash, 'rb')))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /Users/jcarron/Library/CloudStorage/OneDrive-unige.ch/LensIt/lensit/ffs_covs/ell_mat.py:49: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/ellmats/ellmat_11_10/ellmat_hash.pk'>
#   hash_check(pk.load(open(fn_hash, 'rb')), self.hash_dict())
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /Users/jcarron/Library/CloudStorage/OneDrive-unige.ch/LensIt/lensit/sims/sims_generic.py:96: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/120_sims/fsky0016/res10/pixpha/pix_pha_0000/sim_hash.pk'>
#   hash_check(pk.load(open(fn, 'rb')), self.hashdict(), ignore=['lib_dir'])
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /Users/jcarron/Library/CloudStorage/OneDrive-unige.ch/LensIt/lensit/sims/sims_generic.py:96: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/120_sims/fsky0016/res10/pixpha/pix_pha_0001/sim_hash.pk'>
#   hash_check(pk.load(open(fn, 'rb')), self.hashdict(), ignore=['lib_dir'])
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /Users/jcarron/Library/CloudStorage/OneDrive-unige.ch/LensIt/lensit/sims/sims_generic.py:96: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/120_sims/fsky0016/res10/pixpha/pix_pha_0002/sim_hash.pk'>
#   hash_check(pk.load(open(fn, 'rb')), self.hashdict(), ignore=['lib_dir'])
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /Users/jcarron/Library/CloudStorage/OneDrive-unige.ch/LensIt/lensit/sims/ffs_maps.py:212: ResourceWarning: unclosed file <_io.BufferedReader name='/Users/jcarron/OneDrive - unige.ch/LensIt/temp/temp/120_sims/fsky0016/res10/S4/maps/sim_hash.pk'>
#   hash_check(self.hashdict(), pk.load(open(fn_hash, 'rb')))
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# []

# %% [markdown]
# ### This file contains very crude information on the iterator work and likelihood gradient amplitudes:

# %%
cat /Users/jcarron/PyCharmProjects/lensit/temp/iterator_S4_sim000/history_increment.txt
# Out:
# cat: /Users/jcarron/PyCharmProjects/lensit/temp/iterator_S4_sim000/history_increment.txt: No such file or directory

# %% [markdown]
# ### Lensing maps:
# we plot the deflection $\hat \alpha_{LM} = \sqrt{L (L + 1)} \hat \phi_{LM}$

# %%
plm2alphalm = lambda plm : lib_qlm.almxfl(plm, np.arange(lib_qlm.ellmax + 1))
fig, ax = pl.subplots(1, 3, figsize=(18, 6),)
vmax = np.max(np.abs(lib_qlm.alm2map(plm2alphalm(plm_input))))
ax[0].imshow(lib_qlm.alm2map(plm2alphalm(itlib.get_Plm(0, 'p'))), vmax=vmax, vmin=-vmax)
ax[1].imshow(lib_qlm.alm2map(plm2alphalm(itlib.get_Plm(9, 'p'))), vmax=vmax, vmin=-vmax)
ax[2].imshow(lib_qlm.alm2map(plm2alphalm(plm_input)), vmax=vmax, vmin=-vmax)
ax[0].set_title(r'$\hat \alpha^{Q.E.}$', fontsize=20), ax[0].axis('off')
ax[1].set_title(r'$\hat \alpha^{Iter}$', fontsize=20), ax[1].axis('off')
ax[2].set_title(r'$\alpha^{\rm input}$', fontsize=20), ax[2].axis('off')
# Out:
# (Text(0.5, 1.0, '$\\alpha^{\\rm input}$'), (-0.5, 1023.5, 1023.5, -0.5))
